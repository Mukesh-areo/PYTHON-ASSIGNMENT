# %% [markdown]
# ## PYTHON BASIC ASSIGNMENT -13

# %% [markdown]
# ### 1. What advantages do Excel spreadsheets have over CSV spreadsheets?
# Excel advantages over CSV
# 1. It is a binary file that holds information about all the worksheets in a workbook
# 2. An Excel not only stores data but can also do operations on the data
# 3. Files saved in excel cannot be opened or edited by text editors
# 4. large files user is much easier in Excel for the end user. Also,
#     you can have additional functions like selecting individual cells for import,
#     convert dates and time automatically, reading formulas and their results, filters, sorting, etc
# 5. Apart from text, data can also be stored in form of charts and graphs
# 6. Excel can connect to external data sources to fetch data. You can use custom add-in in Excel to increase its functionality.
# 7. Excel allows for Review of Data with detailed tracking and commenting feature
# 8. In Excel, spreadsheets can have values of data types other than strings; cells can have different fonts, sizes,
#    or color settings; cells can have varying widths and heights; adjacent cells can be merged

# %% [markdown]
# ### 2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?
# we pass a File object, obtained from a call to open().

# %%
import csv
exFile = open('Team 2 17-08-21.csv')
exreader = csv.reader(exFile)
exData = list(exreader)
exData
# Out:
# [['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "12'' TK 412  SUCTION line ",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['SL NO ',
#   'DATE',
#   'LINE NAME',
#   'Pipe Dia',
#   'Schedule',
#   'Nominal Thickness (mm)',
#   'Support No.(DRDS Ref)',
#   'Suppor No. (BPC: Ref)',
#   'Site location ',
#   'type of support ',
#   'Scan Length',
#   'Starting point of the scan to Support start (a)',
#   'Support Width (b)',
#   'Support end to End of the Scan (c) ',
#   ' Contact with the support (NC/C )',
#   'SUPPORT START TO CONTACT AREA START',
#   'CONTACT AREA',
#   'Probe Placing area UT Reading',
#   '',
#   'UT Reading at Bottom Portion (4 to 5)',
#   'Micro seconds ',
#   '% WL',
#   'visual observation ',
#   'REMARKS',
#   ''],
#  ['1',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L1',
#   '1',
#   '11x12 junction,West to culvert',
#   '20MM ROD',
#   '690',
#   '200',
#   '290',
#   '200',
#   'C',
#   '50',
#   '180',
#   '7.3,7.5,7.8',
#   '7.7,7.9;8.1',
#   '7.8,7.7,7.9,8.1',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['2',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L2',
#   '2',
#   '11x12 junction,West to culvert',
#   '20MM ROD',
#   '780',
#   '200',
#   '380',
#   '200',
#   'C',
#   '160',
#   '220',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['3',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L3',
#   '3',
#   '11x12 junction,West to culvert',
#   '20MM ROD',
#   '480',
#   '200',
#   '280',
#   '0',
#   'C',
#   '50',
#   '230',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'CICUM WED AT END',
#   '',
#   ''],
#  ['4',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L4',
#   '4',
#   'East to Tank 707',
#   '20MM ROD',
#   '740',
#   '200',
#   '340',
#   '200',
#   'C',
#   '60',
#   '180',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'RHS PROBE PLACING AREA PITTING',
#   '',
#   ''],
#  ['5',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L5',
#   '6',
#   'East to Tank 707',
#   'CONCRETE',
#   '600',
#   '200',
#   '200',
#   '200',
#   'FC',
#   '0',
#   '200',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['6',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L6',
#   '10',
#   'East to G-2C',
#   'CONCRETE WITH MS PLATE',
#   '880',
#   '130',
#   '620',
#   '130',
#   'FC',
#   '0',
#   '620',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['7',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L7',
#   '11',
#   'West to Tank 411 and East to G-2B',
#   'CONCRETE',
#   '320',
#   '0',
#   '120',
#   '200',
#   'FC',
#   '0',
#   '120',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['8',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L8',
#   '12',
#   'West to Tank 411 and East to G-2A',
#   '20MM ROD',
#   '710',
#   '200',
#   '310',
#   '200',
#   'NC',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['9',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L9',
#   '13',
#   'West to Tank 411 and East to G-3C',
#   'CONCRETE',
#   '750',
#   '200',
#   '350',
#   '200',
#   'FC',
#   '0',
#   '350',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['10',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L10',
#   '15',
#   'West to Tank 411 and East to PM-406',
#   'CONCRETE',
#   '370',
#   '200',
#   '170',
#   '0',
#   'FC',
#   '0',
#   '170',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['11',
#   '17/8/2021',
#   'TK 412  SUCTION line ',
#   '12"',
#   '',
#   '',
#   '12L11',
#   '16',
#   'West to Tank 411 and East to G-41',
#   '20 MM ROD',
#   '670',
#   '200',
#   '270',
#   '200',
#   'C',
#   '90',
#   '40',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']]

# %% [markdown]
# ### 3. What modes do File objects for reader and writer objects need to be opened in?
# File objects need to be opened in read-binary ('rb') for Reader objects and write-binary ('wb') for Writer objects

# %% [markdown]
# ### 4. What method takes a list argument and writes it to a CSV file?
# The writerow() method

# %%
opFile = open('output.csv','w')
opWriter = csv.writer(opFile)
csv.writer(opFile).writerow(['egg','orange','milk'])
# Out:
# 17

# %% [markdown]
# ### 5. What do the keyword arguments delimiter and line terminator do?
#  The delimiter argument changes the string used to separate cells in a row.
#  The line terminator argument changes the string used to separate rows.

# %%
import csv
csvFile = open('example.tsv', 'w', newline='')
csvWriter = csv.writer(csvFile, delimiter='\t', lineterminator='\n\n')

# %% [markdown]
# ### 6. What function takes a string of JSON data and returns a Python data structure?
#
# json.loads()

# %% [markdown]
# ### 7. What function takes a Python data structure and returns a string of JSON data?
# json.dumps()
